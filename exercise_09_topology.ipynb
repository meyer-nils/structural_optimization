# %% [markdown]
# # Exercise 09 - Topology optimization for continua

# %% [markdown]
# ## Task 1 - Book shelf
#
# Let us consider a bookshelf that needs a support structure. The design domain is given by a unit square $x \in [0, 1]^2$ and a maximum thickness $d_{max}=0.1$. The left boundary of the domain $\partial \Omega_D$ is fixed to the wall and the top boundary $\partial \Omega_N$ is loaded with a uniform line load representing the weight of books.
#
# <div>
#     <center>
#         <img src="figures/domain.png" width="250"/>
#     </center>
# </div>

# %%
import torch
from simple_fem import FEM

torch.set_default_dtype(torch.double)

# %% [markdown]
# a) Modify the solution from last exercise and increase the number of elements per direction $N$ to 20.

# %%
# Create nodes
N = 20
n1 = torch.linspace(0.0, 1.0, N + 1)
n2 = torch.linspace(0.0, 1.0, N + 1)
n1, n2 = torch.stack(torch.meshgrid(n1, n2, indexing="xy"))
nodes = torch.stack([n1.ravel(), n2.ravel()], dim=1)

# Create elements connecting nodes
elements = []
for j in range(N):
    for i in range(N):
        n0 = i + j * (N + 1)
        elements.append([n0, n0 + 1, n0 + N + 2, n0 + N + 1])

# Load at top
forces = torch.zeros_like(nodes)
forces[N * (N + 1) : (N + 1) * (N + 1), 1] = -1.0 / N

# Constrained displacement at left end
constraints = torch.zeros_like(nodes, dtype=bool)
for i in range(N + 1):
    constraints[i * (N + 1), :] = True

# Thickness
d = 0.1
thickness = d * torch.ones(len(elements))

# Material
E = 1000.0
nu = 0.25

# Create and plot the domain
square = FEM(nodes, elements, forces, constraints, thickness=thickness, E=E, nu=nu)
square.plot()

# %% [markdown]
# To save material, the bookshelf should use only 40% of the given design space, while being as stiff as possible to support many books. We want to achieve this by topology optimization of the component. You are provided with a function that performs root finding with the bisection method from a previous exercise.

# %%
def bisection(f, a, b, max_iter=50, tol=1e-12):
    # Bisection method always finds a root, even with highly non-linear grad
    i = 0
    while (b - a) > tol:
        c = (a + b) / 2.0
        if i > max_iter:
            raise Exception(f"Bisection did not converge in {max_iter} iterations.")
        if f(a) * f(c) > 0:
            a = c
        else:
            b = c
        i += 1
    return c

# %% [markdown]
# b) Implement a topology optimization algorithm with *optimality conditions* in a function named `optimize(fem, rho_0, rho_min, rho_max, V_0, iter=100, xi=0.5, m=0.2, p=1.0, r=0.0)` that takes the FEM model `fem`, the initial density distribution `rho_0`, the minimum and maximum thickness distributions `rho_min, rho_max`, the volume constraint, the maximum iteration count `iter` with a default value of 100, a SIMP penality factor `p` with default 1, and a radius for sensitivity filtering `r` with a default 0.0.

# %%
def optimize(fem, rho_0, rho_min, rho_max, V_0, iter=100, xi=0.5, m=0.2, p=1.0, r=0.0):
    rho = [rho_0]
    vols = d * fem.areas()

    # Check if there is a feasible solution before starting iteration
    if torch.inner(rho_min, vols) > V_0:
        raise Exception("rho_min is not compatible with V_0.")

    # Precompute filter weights
    if r > 0.0:
        H = r - fem.dist
        H[fem.dist > r] = 0.0

    # Iterate solutions
    for k in range(iter):
        # Adjust thickness variables
        fem.thickness = d * rho[k]

        # Compute solution
        u_k, f_k = fem.solve()

        # Compute sensitivities
        w_k = fem.element_strain_energies(u_k)
        sensitivity = -p * d * rho[k] ** (p - 1) * 2.0 * w_k

        # Filter sensitivities (if r provided)
        if r > 0.0:
            sensitivity = H @ (rho[k] * sensitivity) / H.sum(dim=0) / rho[k]

        # For a certain value of mu, apply the iteration scheme
        def make_step(mu):
            G_k = -sensitivity / (mu * vols)
            upper = torch.min(rho_max, (1 + m) * rho[k])
            lower = torch.max(rho_min, (1 - m) * rho[k])
            rho_trial = G_k**xi * rho[k]
            return torch.maximum(torch.minimum(rho_trial, upper), lower)

        # Constraint function
        def g(mu):
            rho_k = make_step(mu)
            return torch.dot(rho_k, vols) - V_0

        # Find the root of g(mu)
        mu = bisection(g, 1e-10, 100.0)

        # Evaluation
        compliance = torch.inner(f_k.ravel(), u_k.ravel())
        print(f"Iteration k={k} - Compliance: {compliance:.5f}")

        rho.append(make_step(mu))

    return rho

# %% [markdown]
# b) Set up the initial design variables $\rho_0=0.5, \rho_{min}=0.01, \rho_{max}=1.0$ and a volume constraint $V_0= 0.5 V_{max}$ with the maximum design volume $V_{max}$.

# %%
# Initial thickness, minimum thickness, maximum thickness
rho_0 = 0.5 * torch.ones(len(square.elements))
rho_min = 0.01 * torch.ones_like(rho_0)
rho_max = 1.0 * torch.ones_like(rho_0)

# Initial volume (40% of maximum design volume)
vols = d * square.areas()
V0 = 0.4 * vols.sum()

# %% [markdown]
# c) Perform the optimization with 80 iterations and the following parameters:
# $$p=2$$
# $$r=0$$

# %%
# Optimize and visualize results
d_opt = optimize(square, rho_0, rho_min, rho_max, V0, iter=80, p=2.0, r=0.0)
square.plot(element_property=d_opt[-1])
# Out:
# Iteration k=0 - Compliance: 0.04077
# Iteration k=1 - Compliance: 0.05096
# Iteration k=2 - Compliance: 0.04601
# Iteration k=3 - Compliance: 0.04332
# Iteration k=4 - Compliance: 0.04199
# Iteration k=5 - Compliance: 0.04137
# Iteration k=6 - Compliance: 0.04115
# Iteration k=7 - Compliance: 0.04136
# Iteration k=8 - Compliance: 0.04160
# Iteration k=9 - Compliance: 0.04185
# Iteration k=10 - Compliance: 0.04210
# Iteration k=11 - Compliance: 0.04242
# Iteration k=12 - Compliance: 0.04283
# Iteration k=13 - Compliance: 0.04329
# Iteration k=14 - Compliance: 0.04386
# Iteration k=15 - Compliance: 0.04451
# Iteration k=16 - Compliance: 0.04514
# Iteration k=17 - Compliance: 0.04563
# Iteration k=18 - Compliance: 0.04591
# Iteration k=19 - Compliance: 0.04600
# Iteration k=20 - Compliance: 0.04605
# Iteration k=21 - Compliance: 0.04610
# Iteration k=22 - Compliance: 0.04615
# Iteration k=23 - Compliance: 0.04617
# Iteration k=24 - Compliance: 0.04618
# Iteration k=25 - Compliance: 0.04618
# Iteration k=26 - Compliance: 0.04619
# Iteration k=27 - Compliance: 0.04620
# Iteration k=28 - Compliance: 0.04621
# Iteration k=29 - Compliance: 0.04621
# Iteration k=30 - Compliance: 0.04620
# Iteration k=31 - Compliance: 0.04620
# Iteration k=32 - Compliance: 0.04620
# Iteration k=33 - Compliance: 0.04620
# Iteration k=34 - Compliance: 0.04621
# Iteration k=35 - Compliance: 0.04623
# Iteration k=36 - Compliance: 0.04625
# Iteration k=37 - Compliance: 0.04628
# Iteration k=38 - Compliance: 0.04631
# Iteration k=39 - Compliance: 0.04635
# Iteration k=40 - Compliance: 0.04639
# Iteration k=41 - Compliance: 0.04643
# Iteration k=42 - Compliance: 0.04646
# Iteration k=43 - Compliance: 0.04648
# Iteration k=44 - Compliance: 0.04650
# Iteration k=45 - Compliance: 0.04652
# Iteration k=46 - Compliance: 0.04654
# Iteration k=47 - Compliance: 0.04657
# Iteration k=48 - Compliance: 0.04659
# Iteration k=49 - Compliance: 0.04661
# Iteration k=50 - Compliance: 0.04664
# Iteration k=51 - Compliance: 0.04666
# Iteration k=52 - Compliance: 0.04668
# Iteration k=53 - Compliance: 0.04669
# Iteration k=54 - Compliance: 0.04671
# Iteration k=55 - Compliance: 0.04672
# Iteration k=56 - Compliance: 0.04672
# Iteration k=57 - Compliance: 0.04671
# Iteration k=58 - Compliance: 0.04669
# Iteration k=59 - Compliance: 0.04668
# Iteration k=60 - Compliance: 0.04667
# Iteration k=61 - Compliance: 0.04665
# Iteration k=62 - Compliance: 0.04664
# Iteration k=63 - Compliance: 0.04662
# Iteration k=64 - Compliance: 0.04661
# Iteration k=65 - Compliance: 0.04660
# Iteration k=66 - Compliance: 0.04659
# Iteration k=67 - Compliance: 0.04658
# Iteration k=68 - Compliance: 0.04658
# Iteration k=69 - Compliance: 0.04657
# Iteration k=70 - Compliance: 0.04656
# Iteration k=71 - Compliance: 0.04656
# Iteration k=72 - Compliance: 0.04656
# Iteration k=73 - Compliance: 0.04655
# Iteration k=74 - Compliance: 0.04655
# Iteration k=75 - Compliance: 0.04655
# Iteration k=76 - Compliance: 0.04654
# Iteration k=77 - Compliance: 0.04654
# Iteration k=78 - Compliance: 0.04654
# Iteration k=79 - Compliance: 0.04654

# %% [markdown]
# d) Plot the evolution of design variables vs. iterations. What does the graph tell you?

# %%
import matplotlib.pyplot as plt

plt.plot(torch.stack(d_opt).detach())
plt.xlabel("Iteration")
plt.ylabel("Values $d_i$")
plt.grid()

# %% [markdown]
# e) Perform the optimization with 250 iterations and the following parameters
# $$p=3$$
# $$r=0.06$$

# %%
# Optimize and visualize results
d_opt = optimize(square, rho_0, rho_min, rho_max, V0, iter=250, p=3.0, r=0.06)
square.plot(element_property=d_opt[-1])
# Out:
# Iteration k=0 - Compliance: 0.04077
# Iteration k=1 - Compliance: 0.05096
# Iteration k=2 - Compliance: 0.04601
# Iteration k=3 - Compliance: 0.04347
# Iteration k=4 - Compliance: 0.04296
# Iteration k=5 - Compliance: 0.04406
# Iteration k=6 - Compliance: 0.04662
# Iteration k=7 - Compliance: 0.05044
# Iteration k=8 - Compliance: 0.05464
# Iteration k=9 - Compliance: 0.05907
# Iteration k=10 - Compliance: 0.06393
# Iteration k=11 - Compliance: 0.06906
# Iteration k=12 - Compliance: 0.07463
# Iteration k=13 - Compliance: 0.08055
# Iteration k=14 - Compliance: 0.08660
# Iteration k=15 - Compliance: 0.09313
# Iteration k=16 - Compliance: 0.10009
# Iteration k=17 - Compliance: 0.10693
# Iteration k=18 - Compliance: 0.10955
# Iteration k=19 - Compliance: 0.10647
# Iteration k=20 - Compliance: 0.10330
# Iteration k=21 - Compliance: 0.10039
# Iteration k=22 - Compliance: 0.09782
# Iteration k=23 - Compliance: 0.09529
# Iteration k=24 - Compliance: 0.09283
# Iteration k=25 - Compliance: 0.09075
# Iteration k=26 - Compliance: 0.08891
# Iteration k=27 - Compliance: 0.08732
# Iteration k=28 - Compliance: 0.08598
# Iteration k=29 - Compliance: 0.08463
# Iteration k=30 - Compliance: 0.08309
# Iteration k=31 - Compliance: 0.08179
# Iteration k=32 - Compliance: 0.08085
# Iteration k=33 - Compliance: 0.08016
# Iteration k=34 - Compliance: 0.07941
# Iteration k=35 - Compliance: 0.07881
# Iteration k=36 - Compliance: 0.07826
# Iteration k=37 - Compliance: 0.07749
# Iteration k=38 - Compliance: 0.07678
# Iteration k=39 - Compliance: 0.07640
# Iteration k=40 - Compliance: 0.07640
# Iteration k=41 - Compliance: 0.07670
# Iteration k=42 - Compliance: 0.07710
# Iteration k=43 - Compliance: 0.07762
# Iteration k=44 - Compliance: 0.07722
# Iteration k=45 - Compliance: 0.07560
# Iteration k=46 - Compliance: 0.07399
# Iteration k=47 - Compliance: 0.07243
# Iteration k=48 - Compliance: 0.07099
# Iteration k=49 - Compliance: 0.06963
# Iteration k=50 - Compliance: 0.06832
# Iteration k=51 - Compliance: 0.06705
# Iteration k=52 - Compliance: 0.06586
# Iteration k=53 - Compliance: 0.06475
# Iteration k=54 - Compliance: 0.06385
# Iteration k=55 - Compliance: 0.06295
# Iteration k=56 - Compliance: 0.06148
# Iteration k=57 - Compliance: 0.05991
# Iteration k=58 - Compliance: 0.05850
# Iteration k=59 - Compliance: 0.05726
# Iteration k=60 - Compliance: 0.05613
# Iteration k=61 - Compliance: 0.05509
# Iteration k=62 - Compliance: 0.05412
# Iteration k=63 - Compliance: 0.05320
# Iteration k=64 - Compliance: 0.05236
# Iteration k=65 - Compliance: 0.05161
# Iteration k=66 - Compliance: 0.05095
# Iteration k=67 - Compliance: 0.05039
# Iteration k=68 - Compliance: 0.04996
# Iteration k=69 - Compliance: 0.04962
# Iteration k=70 - Compliance: 0.04932
# Iteration k=71 - Compliance: 0.04901
# Iteration k=72 - Compliance: 0.04872
# Iteration k=73 - Compliance: 0.04845
# Iteration k=74 - Compliance: 0.04820
# Iteration k=75 - Compliance: 0.04797
# Iteration k=76 - Compliance: 0.04777
# Iteration k=77 - Compliance: 0.04760
# Iteration k=78 - Compliance: 0.04745
# Iteration k=79 - Compliance: 0.04732
# Iteration k=80 - Compliance: 0.04720
# Iteration k=81 - Compliance: 0.04711
# Iteration k=82 - Compliance: 0.04703
# Iteration k=83 - Compliance: 0.04697
# Iteration k=84 - Compliance: 0.04691
# Iteration k=85 - Compliance: 0.04685
# Iteration k=86 - Compliance: 0.04678
# Iteration k=87 - Compliance: 0.04673
# Iteration k=88 - Compliance: 0.04667
# Iteration k=89 - Compliance: 0.04661
# Iteration k=90 - Compliance: 0.04655
# Iteration k=91 - Compliance: 0.04650
# Iteration k=92 - Compliance: 0.04644
# Iteration k=93 - Compliance: 0.04639
# Iteration k=94 - Compliance: 0.04634
# Iteration k=95 - Compliance: 0.04629
# Iteration k=96 - Compliance: 0.04624
# Iteration k=97 - Compliance: 0.04620
# Iteration k=98 - Compliance: 0.04616
# Iteration k=99 - Compliance: 0.04611
# Iteration k=100 - Compliance: 0.04608
# Iteration k=101 - Compliance: 0.04607
# Iteration k=102 - Compliance: 0.04606
# Iteration k=103 - Compliance: 0.04605
# Iteration k=104 - Compliance: 0.04604
# Iteration k=105 - Compliance: 0.04604
# Iteration k=106 - Compliance: 0.04604
# Iteration k=107 - Compliance: 0.04602
# Iteration k=108 - Compliance: 0.04601
# Iteration k=109 - Compliance: 0.04599
# Iteration k=110 - Compliance: 0.04597
# Iteration k=111 - Compliance: 0.04594
# Iteration k=112 - Compliance: 0.04591
# Iteration k=113 - Compliance: 0.04588
# Iteration k=114 - Compliance: 0.04584
# Iteration k=115 - Compliance: 0.04579
# Iteration k=116 - Compliance: 0.04574
# Iteration k=117 - Compliance: 0.04568
# Iteration k=118 - Compliance: 0.04563
# Iteration k=119 - Compliance: 0.04558
# Iteration k=120 - Compliance: 0.04555
# Iteration k=121 - Compliance: 0.04551
# Iteration k=122 - Compliance: 0.04546
# Iteration k=123 - Compliance: 0.04543
# Iteration k=124 - Compliance: 0.04539
# Iteration k=125 - Compliance: 0.04536
# Iteration k=126 - Compliance: 0.04533
# Iteration k=127 - Compliance: 0.04530
# Iteration k=128 - Compliance: 0.04527
# Iteration k=129 - Compliance: 0.04523
# Iteration k=130 - Compliance: 0.04519
# Iteration k=131 - Compliance: 0.04516
# Iteration k=132 - Compliance: 0.04514
# Iteration k=133 - Compliance: 0.04513
# Iteration k=134 - Compliance: 0.04512
# Iteration k=135 - Compliance: 0.04511
# Iteration k=136 - Compliance: 0.04511
# Iteration k=137 - Compliance: 0.04509
# Iteration k=138 - Compliance: 0.04508
# Iteration k=139 - Compliance: 0.04506
# Iteration k=140 - Compliance: 0.04505
# Iteration k=141 - Compliance: 0.04505
# Iteration k=142 - Compliance: 0.04504
# Iteration k=143 - Compliance: 0.04504
# Iteration k=144 - Compliance: 0.04503
# Iteration k=145 - Compliance: 0.04503
# Iteration k=146 - Compliance: 0.04502
# Iteration k=147 - Compliance: 0.04501
# Iteration k=148 - Compliance: 0.04498
# Iteration k=149 - Compliance: 0.04496
# Iteration k=150 - Compliance: 0.04494
# Iteration k=151 - Compliance: 0.04492
# Iteration k=152 - Compliance: 0.04491
# Iteration k=153 - Compliance: 0.04490
# Iteration k=154 - Compliance: 0.04489
# Iteration k=155 - Compliance: 0.04489
# Iteration k=156 - Compliance: 0.04489
# Iteration k=157 - Compliance: 0.04488
# Iteration k=158 - Compliance: 0.04488
# Iteration k=159 - Compliance: 0.04488
# Iteration k=160 - Compliance: 0.04488
# Iteration k=161 - Compliance: 0.04488
# Iteration k=162 - Compliance: 0.04488
# Iteration k=163 - Compliance: 0.04489
# Iteration k=164 - Compliance: 0.04489
# Iteration k=165 - Compliance: 0.04490
# Iteration k=166 - Compliance: 0.04490
# Iteration k=167 - Compliance: 0.04491
# Iteration k=168 - Compliance: 0.04491
# Iteration k=169 - Compliance: 0.04491
# Iteration k=170 - Compliance: 0.04491
# Iteration k=171 - Compliance: 0.04491
# Iteration k=172 - Compliance: 0.04491
# Iteration k=173 - Compliance: 0.04491
# Iteration k=174 - Compliance: 0.04491
# Iteration k=175 - Compliance: 0.04490
# Iteration k=176 - Compliance: 0.04490
# Iteration k=177 - Compliance: 0.04490
# Iteration k=178 - Compliance: 0.04490
# Iteration k=179 - Compliance: 0.04490
# Iteration k=180 - Compliance: 0.04490
# Iteration k=181 - Compliance: 0.04489
# Iteration k=182 - Compliance: 0.04489
# Iteration k=183 - Compliance: 0.04489
# Iteration k=184 - Compliance: 0.04489
# Iteration k=185 - Compliance: 0.04489
# Iteration k=186 - Compliance: 0.04489
# Iteration k=187 - Compliance: 0.04489
# Iteration k=188 - Compliance: 0.04489
# Iteration k=189 - Compliance: 0.04489
# Iteration k=190 - Compliance: 0.04490
# Iteration k=191 - Compliance: 0.04490
# Iteration k=192 - Compliance: 0.04490
# Iteration k=193 - Compliance: 0.04490
# Iteration k=194 - Compliance: 0.04490
# Iteration k=195 - Compliance: 0.04491
# Iteration k=196 - Compliance: 0.04491
# Iteration k=197 - Compliance: 0.04491
# Iteration k=198 - Compliance: 0.04490
# Iteration k=199 - Compliance: 0.04490
# Iteration k=200 - Compliance: 0.04490
# Iteration k=201 - Compliance: 0.04489
# Iteration k=202 - Compliance: 0.04489
# Iteration k=203 - Compliance: 0.04488
# Iteration k=204 - Compliance: 0.04488
# Iteration k=205 - Compliance: 0.04488
# Iteration k=206 - Compliance: 0.04487
# Iteration k=207 - Compliance: 0.04487
# Iteration k=208 - Compliance: 0.04487
# Iteration k=209 - Compliance: 0.04486
# Iteration k=210 - Compliance: 0.04486
# Iteration k=211 - Compliance: 0.04486
# Iteration k=212 - Compliance: 0.04485
# Iteration k=213 - Compliance: 0.04485
# Iteration k=214 - Compliance: 0.04485
# Iteration k=215 - Compliance: 0.04485
# Iteration k=216 - Compliance: 0.04485
# Iteration k=217 - Compliance: 0.04484
# Iteration k=218 - Compliance: 0.04484
# Iteration k=219 - Compliance: 0.04484
# Iteration k=220 - Compliance: 0.04484
# Iteration k=221 - Compliance: 0.04484
# Iteration k=222 - Compliance: 0.04484
# Iteration k=223 - Compliance: 0.04484
# Iteration k=224 - Compliance: 0.04484
# Iteration k=225 - Compliance: 0.04483
# Iteration k=226 - Compliance: 0.04483
# Iteration k=227 - Compliance: 0.04483
# Iteration k=228 - Compliance: 0.04483
# Iteration k=229 - Compliance: 0.04483
# Iteration k=230 - Compliance: 0.04483
# Iteration k=231 - Compliance: 0.04483
# Iteration k=232 - Compliance: 0.04483
# Iteration k=233 - Compliance: 0.04483
# Iteration k=234 - Compliance: 0.04483
# Iteration k=235 - Compliance: 0.04483
# Iteration k=236 - Compliance: 0.04483
# Iteration k=237 - Compliance: 0.04483
# Iteration k=238 - Compliance: 0.04483
# Iteration k=239 - Compliance: 0.04483
# Iteration k=240 - Compliance: 0.04483
# Iteration k=241 - Compliance: 0.04483
# Iteration k=242 - Compliance: 0.04483
# Iteration k=243 - Compliance: 0.04483
# Iteration k=244 - Compliance: 0.04483
# Iteration k=245 - Compliance: 0.04483
# Iteration k=246 - Compliance: 0.04483
# Iteration k=247 - Compliance: 0.04483
# Iteration k=248 - Compliance: 0.04483
# Iteration k=249 - Compliance: 0.04483

# %% [markdown]
# f) How do you interpret the design? Decide which manufacturing process you would like to use and use a CAD software to create a design based on your optimization.
